# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Question A

# %%
# Loading csv file to jupyter notebook using pandas
df = pd.read_csv('Airbnb_UK_2022.csv')

# %%
df
# Out:
#        host_id                                               name  \
# 0        60302                Bright Chelsea  Apartment. Chelsea!
# 1       554519             JESSIE the narrowboat in Little Venice
# 2      1481851                Notting Hill church stay in Heaven!
# 3        41759  Battersea live/work artist house, garden communal
# 4       586671                    DOUBLE ROOM NEAR CENTRAL LONDON
# ...        ...                                                ...
# 8434   7879433               Unique boat living in central London
# 8435  39903308  A Beautiful Room with River Views. CENTRAL LONDON
# 8436     24129               Cosy 2 bed and breakfast family home
# 8437   1132775                             River view Tate Modern
# 8438   1706966  Luxury 4 bed and breakfast house, 100m to rive...
#
#                                             description       host_name  \
# 0     lots of windows and light  st luke s gardens a...        Philippa
# ...

# %% [markdown]
# Question B

# %%
#Assume Host id as 1706966
host_id = 1706966
result = df.loc[df['host_id'] == host_id, ['name', 'host_name', 'description', 'host_location', 'host_since']]

# %%
result
# Out:
#                                                    name       host_name  \
# 8438  Luxury 4 bed and breakfast house, 100m to rive...  Asher   Aileen
#
#                                             description host_location  \
# 8438  forget your worries in this spacious and seren...        London
#
#      host_since
# 8438   06-02-12

# %% [markdown]
# Question C

# %%
#assume london as location
location = "London"
df_filtered = df.loc[df['host_location'] == location, ['host_name', 'property_type', 'price', 'minimum_nights', 'maximum_nights']]

# %%
df_filtered
# Out:
#            host_name property_type  price  minimum_nights  maximum_nights
# 1                Meg     houseboat    204               2              30
# 2              Tania   rental unit    297              14             365
# 3                Joe     townhouse    195               3            1125
# 4                Joe     townhouse     30               7             730
# 5               Olga   rental unit    136               5              90
# ...              ...           ...    ...             ...             ...
# 8432          Andrew         condo    270               4             365
# 8434          Robert          boat    150               3              30
# 8435          Daniel   rental unit    120               2            1125
# 8437            Mark         condo    201               3              28
# 8438  Asher   Aileen          home    246               3             365
#
# [7704 rows x 5 columns]

# %% [markdown]
# Question D

# %%
specified_property_type = 'apartment' # assume apartment as property type

df_filtered1 = df.loc[df['property_type'] == specified_property_type, ['room_type', 'accommodates', 'bathrooms_text', 'bedrooms', 'beds']]
df_filtered1
# Out:
#          room_type  accommodates bathrooms_text  bedrooms  beds
# 1840  Private room             2         1 bath         1     1

# %% [markdown]
# Question E

# %%
#4 replace 'host_location' with the desired location and 'host_id' with the desired host id
location = 'London'
host_id = 554519
columns = ['name', 'property_type', 'price']

# filter the data for the desired location and host id
host_data = df.loc[(df['host_location'] == location) & (df['host_id'] == host_id), columns]

# display the result
host_data
# Out:
#                                      name property_type  price
# 1  JESSIE the narrowboat in Little Venice     houseboat    204
